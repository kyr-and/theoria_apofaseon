# %% [markdown]
# # Ομαδοποίηση των χρηστών αναλογώς το πως βαθμολογούν το κάθε είδος ταινίας και τα χαρακτηριστικά τους (με αλγόριθμο KMeans)

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans

# %% [markdown]
# ## Import Datasets

# %%
# Movies
movies_df = pd.read_csv('data/movies.csv', sep='\t')
movies_df = movies_df.drop(movies_df.columns[0], axis=1)

# Users
users_df = pd.read_csv('data/users.csv', sep='\t')
users_df = users_df.drop(users_df.columns[0], axis=1)

# Ratings
ratings_df = pd.read_csv('data/ratings.csv', sep=';')
ratings_df = ratings_df.drop(ratings_df.columns[0], axis=1)

# %% [markdown]
# ## Βρίσκουμε το average rating κάθε είδους για κάθε χρήστη

# %% [markdown]
# ### User ids

# %%
user_ids = np.array(users_df.user_id)
user_ids
# Out:
# array([   1,    2,    3, ..., 6038, 6039, 6040])

# %% [markdown]
# ### Παράδειγμα για 1 user

# %%
test_id = 1

ratings_curr_user_df = ratings_df[ratings_df.user_id == test_id]
ratings_curr_user_df.head()
# Out:
#    user_id  movie_id  rating  timestamp
# 0        1      1193       5  978300760
# 1        1       661       3  978302109
# 2        1       914       3  978301968
# 3        1      3408       4  978300275
# 4        1      2355       5  978824291

# %%
# merge με τα movies
# merge right για να πάρουμε μόνο τις ταινίες που έχουν rating
curr_user_merged_df = movies_df.merge(ratings_curr_user_df, on='movie_id', how='right')
curr_user_merged_df.head()
# Out:
#    movie_id                                   title  \
# 0      1193  One Flew Over the Cuckoo's Nest (1975)
# 1       661        James and the Giant Peach (1996)
# 2       914                     My Fair Lady (1964)
# 3      3408                  Erin Brockovich (2000)
# 4      2355                    Bug's Life, A (1998)
#
#                          genres  user_id  rating  timestamp
# 0                         Drama        1       5  978300760
# 1  Animation|Children's|Musical        1       3  978302109
# 2               Musical|Romance        1       3  978301968
# 3                         Drama        1       4  978300275
# 4   Animation|Children's|Comedy        1       5  978824291

# %% [markdown]
# ### Θέλουμε να χωρίσουμε τα Genres

# %% [markdown]
# #### Για να κάνουμε split μπορούμε να χρησιμοποιήσουμε τη μέθοδο assign()
# -> https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.assign.html

# %%
split_genres_test = curr_user_merged_df.assign(Genre=curr_user_merged_df.genres.str.split(r'|'))
split_genres_test.head()
# Out:
#    movie_id                                   title  \
# 0      1193  One Flew Over the Cuckoo's Nest (1975)
# 1       661        James and the Giant Peach (1996)
# 2       914                     My Fair Lady (1964)
# 3      3408                  Erin Brockovich (2000)
# 4      2355                    Bug's Life, A (1998)
#
#                          genres  user_id  rating  timestamp  \
# 0                         Drama        1       5  978300760
# 1  Animation|Children's|Musical        1       3  978302109
# 2               Musical|Romance        1       3  978301968
# 3                         Drama        1       4  978300275
# 4   Animation|Children's|Comedy        1       5  978824291
#
#                               Genre
# 0                           [Drama]
# 1  [Animation, Children's, Musical]
# 2                [Musical, Romance]
# 3                           [Drama]
# 4   [Animation, Children's, Comedy]

# %% [markdown]
# #### Μπορούμε να δημιουργήσουμε rows από array ενός column με την explode()
# -> https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.explode.html

# %%
split_genres_test.explode('Genre').head()
# Out:
#    movie_id                                   title  \
# 0      1193  One Flew Over the Cuckoo's Nest (1975)
# 1       661        James and the Giant Peach (1996)
# 1       661        James and the Giant Peach (1996)
# 1       661        James and the Giant Peach (1996)
# 2       914                     My Fair Lady (1964)
#
#                          genres  user_id  rating  timestamp       Genre
# 0                         Drama        1       5  978300760       Drama
# 1  Animation|Children's|Musical        1       3  978302109   Animation
# 1  Animation|Children's|Musical        1       3  978302109  Children's
# 1  Animation|Children's|Musical        1       3  978302109     Musical
# 2               Musical|Romance        1       3  978301968     Musical

# %% [markdown]
# #### Επίσης μπορούμε να πάρουμε όλα τα διαφορετικά genres

# %%
movies_df["genres"].str.split('|').explode()
# Out:
# 0        Animation
# 0       Children's
# 0           Comedy
# 1        Adventure
# 1       Children's
#            ...
# 3879         Drama
# 3880         Drama
# 3881         Drama
# 3882         Drama
# 3882      Thriller
# Name: genres, Length: 6408, dtype: object

# %%
unique_genres = movies_df["genres"].str.split('|').explode().unique()
unique_genres
# Out:
# array(['Animation', "Children's", 'Comedy', 'Adventure', 'Fantasy',
#        'Romance', 'Drama', 'Action', 'Crime', 'Thriller', 'Horror',
#        'Sci-Fi', 'Documentary', 'War', 'Musical', 'Mystery', 'Film-Noir',
#        'Western'], dtype=object)

# %% [markdown]
# ### Οπότε έχουμε:

# %%
# Σπάμε το column genres
avg_ratings_per_genre_curr_user_df = curr_user_merged_df.assign(Genre=curr_user_merged_df.genres.str.split(r'|')).explode('Genre')
avg_ratings_per_genre_curr_user_df.head(7)
# Out:
#    movie_id                                   title  \
# 0      1193  One Flew Over the Cuckoo's Nest (1975)
# 1       661        James and the Giant Peach (1996)
# 1       661        James and the Giant Peach (1996)
# 1       661        James and the Giant Peach (1996)
# 2       914                     My Fair Lady (1964)
# 2       914                     My Fair Lady (1964)
# 3      3408                  Erin Brockovich (2000)
#
#                          genres  user_id  rating  timestamp       Genre
# 0                         Drama        1       5  978300760       Drama
# 1  Animation|Children's|Musical        1       3  978302109   Animation
# 1  Animation|Children's|Musical        1       3  978302109  Children's
# 1  Animation|Children's|Musical        1       3  978302109     Musical
# 2               Musical|Romance        1       3  978301968     Musical
# 2               Musical|Romance        1       3  978301968     Romance
# 3                         Drama        1       4  978300275       Drama

# %%
# Δεν θα χρειαστούμε τον τίτλο, τα timestamps και τα αρχικά genres
avg_ratings_per_genre_curr_user_df.drop(['genres', 'timestamp', 'title'], axis=1, inplace=True)
avg_ratings_per_genre_curr_user_df
# Out:
#     movie_id  user_id  rating       Genre
# 0       1193        1       5       Drama
# 1        661        1       3   Animation
# 1        661        1       3  Children's
# 1        661        1       3     Musical
# 2        914        1       3     Musical
# ..       ...      ...     ...         ...
# 50      3114        1       4      Comedy
# 51       608        1       4       Crime
# 51       608        1       4       Drama
# 51       608        1       4    Thriller
# 52      1246        1       4       Drama
#
# [116 rows x 4 columns]

# %%
# Βρίσκουμε τα average ratings χρησιμοποιώντας το function mean()
avg_ratings_per_genre_curr_user_df = avg_ratings_per_genre_curr_user_df.groupby('Genre').rating.mean()
avg_ratings_per_genre_curr_user_df
# Out:
# Genre
# Action        4.200000
# Adventure     4.000000
# Animation     4.111111
# Children's    4.250000
# Comedy        4.142857
# Crime         4.000000
# Drama         4.428571
# Fantasy       4.000000
# Musical       4.285714
# Romance       3.666667
# Sci-Fi        4.333333
# Thriller      3.666667
# War           5.000000
# Name: rating, dtype: float64

# %% [markdown]
# #### Βάζουμε όλα τα genres (μπορεί ο χρήστης να μην έχει βαθμολογίες σε μερικά genres... τα κάνουμε fill με 0)
# -> https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.reindex.html

# %%
avg_ratings_per_genre_curr_user_df = avg_ratings_per_genre_curr_user_df.reindex(unique_genres).fillna(0)
avg_ratings_per_genre_curr_user_df.sort_index(inplace=True) # sort για να έχουν όλοι οι χρήστες την ίδια σειρά
avg_ratings_per_genre_curr_user_df
# Out:
# Genre
# Action         4.200000
# Adventure      4.000000
# Animation      4.111111
# Children's     4.250000
# Comedy         4.142857
# Crime          4.000000
# Documentary    0.000000
# Drama          4.428571
# Fantasy        4.000000
# Film-Noir      0.000000
# Horror         0.000000
# Musical        4.285714
# Mystery        0.000000
# Romance        3.666667
# Sci-Fi         4.333333
# Thriller       3.666667
# War            5.000000
# Western        0.000000
# Name: rating, dtype: float64

# %% [markdown]
# ### Φτιάχνουμε το array που θα κάνουμε fit στον KMeans
# (πρέπει να το κάνουμε για κάθε χρήστη και στη συνέχεια να τα ενώσουμε)

# %%
kmeans_ratings_data = np.array(avg_ratings_per_genre_curr_user_df.values)
kmeans_ratings_data
# Out:
# array([4.2       , 4.        , 4.11111111, 4.25      , 4.14285714,
#        4.        , 0.        , 4.42857143, 4.        , 0.        ,
#        0.        , 4.28571429, 0.        , 3.66666667, 4.33333333,
#        3.66666667, 5.        , 0.        ])

# %%
# Θέλουμε να βάλουμε και τα χαρακτηριστικά του χρήστη
user_data = users_df[users_df.user_id == test_id]
user_data
# Out:
#    user_id gender  age  occupation zipcode  age_desc      occ_desc
# 0        1      F    1          10   48067  Under 18  K-12 student

# %% [markdown]
# #### Μετατρέπουμε τα columns gender, age_desc σε categorical data

# %%
new_users_df = users_df
new_users_df.gender = new_users_df.gender.astype('category')
new_users_df.age_desc = new_users_df.age_desc.astype('category')
new_users_df.head()
# Out:
#    user_id gender  age  occupation zipcode  age_desc              occ_desc
# 0        1      F    1          10   48067  Under 18          K-12 student
# 1        2      M   56          16   70072       56+         self-employed
# 2        3      M   25          15   55117     25-34             scientist
# 3        4      M   45           7   02460     45-49  executive/managerial
# 4        5      M   25          20   55455     25-34                writer

# %%
curr_user_data = new_users_df[new_users_df.user_id == test_id]
curr_user_data
# Out:
#    user_id gender  age  occupation zipcode  age_desc      occ_desc
# 0        1      F    1          10   48067  Under 18  K-12 student

# %% [markdown]
# ### Παίρνουμε το gender, occupation, age_desc

# %%
kmeans_curr_user_data = np.append(kmeans_ratings_data, curr_user_data.gender.cat.codes) # gender categorical code
kmeans_curr_user_data = np.append(kmeans_curr_user_data, curr_user_data.occupation) # occupation (already coded)
kmeans_curr_user_data = np.append(kmeans_curr_user_data, curr_user_data.age_desc.cat.codes) # age description categorical code
kmeans_curr_user_data
# Out:
# array([ 4.2       ,  4.        ,  4.11111111,  4.25      ,  4.14285714,
#         4.        ,  0.        ,  4.42857143,  4.        ,  0.        ,
#         0.        ,  4.28571429,  0.        ,  3.66666667,  4.33333333,
#         3.66666667,  5.        ,  0.        ,  0.        , 10.        ,
#         6.        ])

# %% [markdown]
# ### **Θα πρέπει να το κάνουμε για κάθε χρήστη και τέλος να τα βάλουμε σε ένα array όλα μαζί

# %%
kmeans_complete = []
kmeans_complete.append(kmeans_curr_user_data)
kmeans_complete
# Out:
# [array([ 4.2       ,  4.        ,  4.11111111,  4.25      ,  4.14285714,
#          4.        ,  0.        ,  4.42857143,  4.        ,  0.        ,
#          0.        ,  4.28571429,  0.        ,  3.66666667,  4.33333333,
#          3.66666667,  5.        ,  0.        ,  0.        , 10.        ,
#          6.        ])]

# %%
# Random data απλά για να δοκιμάσουμε τη λειτουργία του KMeans
dummy_data = np.random.rand(21)
kmeans_complete.append(dummy_data)
kmeans_complete
# Out:
# [array([ 4.2       ,  4.        ,  4.11111111,  4.25      ,  4.14285714,
#          4.        ,  0.        ,  4.42857143,  4.        ,  0.        ,
#          0.        ,  4.28571429,  0.        ,  3.66666667,  4.33333333,
#          3.66666667,  5.        ,  0.        ,  0.        , 10.        ,
#          6.        ]),
#  array([0.12926058, 0.16067352, 0.11277938, 0.45035444, 0.77362811,
#         0.86880245, 0.24036277, 0.71680226, 0.07220089, 0.3634009 ,
#         0.40638678, 0.00899036, 0.10798724, 0.73774377, 0.47526013,
#         0.84632498, 0.95937888, 0.1903338 , 0.8079683 , 0.93221238,
#         0.95147036])]

# %% [markdown]
# ## Implement τον KMeans

# %%
kmeans = KMeans(n_clusters=2)
kmeans.fit(kmeans_complete)
# Out:
# KMeans(n_clusters=2)

# %%
# Prediction σε ποια 'ομάδα' ανήκει κάθε χρήστης
y_kmeans = kmeans.predict(kmeans_complete)
y_kmeans
# Out:
# array([1, 0], dtype=int32)

# %% [markdown]
# # Πρέπει να κάνουμε την διαδικασία αυτή για όλους τους χρήστες

# %%
def get_average_user_ratings_by_genre(id):
    ratings_curr_user_df = ratings_df[ratings_df.user_id == id]
    curr_user_merged_df = movies_df.merge(ratings_curr_user_df, on='movie_id', how='right')
    ratings_per_genre_curr_user_df = curr_user_merged_df.assign(Genre=curr_user_merged_df.genres.str.split(r'|')).explode('Genre')
    avg_ratings_per_genre_curr_user = ratings_per_genre_curr_user_df.groupby('Genre').rating.mean()
    avg_ratings_per_genre_curr_user = avg_ratings_per_genre_curr_user.reindex(unique_genres).fillna(0)
    avg_ratings_per_genre_curr_user.sort_index(inplace=True)
    return np.array(avg_ratings_per_genre_curr_user.values)

# %%
def get_user_info(id):
    curr_user_data = users_df[users_df.user_id == id]
    user_info = np.append(curr_user_data.gender.cat.codes, curr_user_data.occupation)
    user_info = np.append(user_info, curr_user_data.age_desc.cat.codes)
    return user_info

# %%
user_ids = np.array(users_df.user_id) # Πάιρνουμε array με όλα τα ids από το users dataframe
kmeans_complete_dataset = [] # Initialize το array

# Loop για κάθε user και δημιουργία array με τα ratings του χρήστη σε κάθε είδος ΚΑΙ τα βασικά χαρακτηριστικά του (age, occupation etc...)
for user_id in user_ids:
    kmeans_avg_ratings_dataset = get_average_user_ratings_by_genre(user_id)
    kmeans_user_info_dataset = get_user_info(user_id)

    kmeans_curr_user_dataset = np.append(kmeans_avg_ratings_dataset, kmeans_user_info_dataset)
    kmeans_complete_dataset.append(kmeans_curr_user_dataset)

# %%
kmeans_complete_dataset
# Out:
# [array([ 4.2       ,  4.        ,  4.11111111,  4.25      ,  4.14285714,
#          4.        ,  0.        ,  4.42857143,  4.        ,  0.        ,
#          0.        ,  4.28571429,  0.        ,  3.66666667,  4.33333333,
#          3.66666667,  5.        ,  0.        ,  0.        , 10.        ,
#          6.        ]),
#  array([ 3.5       ,  3.73684211,  0.        ,  0.        ,  3.56      ,
#          3.58333333,  0.        ,  3.89873418,  3.        ,  4.        ,
#          3.        ,  0.        ,  3.33333333,  3.70833333,  3.58823529,
#          3.48387097,  3.73333333,  4.33333333,  1.        , 16.        ,
#          5.        ]),
#  array([ 3.95652174,  4.        ,  4.        ,  4.        ,  3.76666667,
#          0.        ,  0.        ,  4.        ,  4.5       ,  0.        ,
#          2.66666667,  4.        ,  3.        ,  3.8       ,  3.83333333,
#          3.8       ,  4.        ,  4.66666667,  1.        , 15.        ,
#          1.        ]),
#  array([4.15789474, 3.83333333, 0.        , 4.        , 0.        ,
#         5.        , 0.        , 4.16666667, 4.5       , 0.        ,
#         4.33333333, 0.        , 0.        , 4.        , 3.55555556,
#         3.5       , 3.33333333, 4.5       , 1.        , 7.        ,
#         3.        ]),
#  array([ 2.61290323,  3.        ,  4.        ,  3.83333333,  3.41071429,
#          3.28571429,  3.66666667,  3.09615385,  0.        ,  4.        ,
#          2.8       ,  3.33333333,  3.125     ,  3.1       ,  3.06666667,
#          2.84615385,  3.5       ,  4.        ,  1.        , 20.        ,
#          1.        ]),
#  array([4.        , 3.75      , 4.22222222, 3.875     , 3.75      ,
#         3.        , 0.        , 3.72727273, 3.        , 0.        ,
#         0.        , 4.31578947, 0.        , 4.        , 3.5       ,
#         3.66666667, 4.        , 3.625     , 0.        , 9.        ,
#         4.        ]),
#  array([4.31034483, 4.625     , 0.        , 0.        , 4.33333333,
#         4.        , 0.        , 4.        , 0.        , 0.        ,
#         5.        , 0.        , 4.        , 4.        , 4.3       ,
#         4.6       , 4.75      , 0.        , 1.        , 1.        ,
#         2.        ]),
#  array([ 4.02777778,  3.88888889,  4.25      ,  3.        ,  3.88888889,
#          4.        ,  0.        ,  3.81481481,  0.        ,  0.        ,
#          5.        ,  4.        ,  3.5       ,  4.06666667,  4.46153846,
#          4.03448276,  4.2       ,  4.        ,  1.        , 12.        ,
#          1.        ]),
#  array([ 3.5       ,  3.42857143,  4.11111111,  4.2       ,  3.74074074,
#          3.75      ,  3.5       ,  3.88888889,  3.        ,  4.        ,
#          2.        ,  0.        ,  4.        ,  3.55555556,  3.88888889,
#          3.62962963,  4.14285714,  5.        ,  1.        , 17.        ,
#          1.        ]),
#  array([3.91358025, 4.11428571, 4.3030303 , 4.109375  , 4.13661202,
#         3.6       , 4.        , 4.18103448, 4.31578947, 3.5       ,
#         4.        , 4.43243243, 3.625     , 4.37313433, 4.18309859,
#         4.22222222, 3.83333333, 3.875     , 0.        , 1.        ,
#         2.        ]),
#  array([3.55555556, 3.125     , 1.        , 1.66666667, 3.16666667,
#         4.42857143, 2.5       , 3.68518519, 2.5       , 0.        ,
#         3.        , 3.66666667, 3.66666667, 3.09090909, 1.75      ,
#         3.44444444, 3.75      , 3.        , 0.        , 1.        ,
#         1.        ]),
#  array([ 3.83333333,  4.66666667,  0.        ,  5.        ,  3.28571429,
#          3.66666667,  0.        ,  4.33333333,  0.        ,  3.        ,
#          3.        ,  5.        ,  3.        ,  3.        ,  4.        ,
#          4.33333333,  3.        ,  0.        ,  1.        , 12.        ,
#          1.        ]),
#  array([3.39393939, 3.33333333, 3.        , 3.33333333, 3.        ,
#         3.25      , 0.        , 3.86363636, 3.21428571, 3.        ,
#         3.33333333, 3.5       , 3.        , 3.30769231, 3.54054054,
#         3.45      , 4.22222222, 2.66666667, 1.        , 1.        ,
#         3.        ]),
#  array([3.25      , 0.        , 0.        , 0.        , 2.875     ,
#         3.33333333, 0.        , 3.53846154, 0.        , 0.        ,
#         2.5       , 0.        , 5.        , 3.5       , 3.5       ,
#         2.75      , 5.        , 0.        , 1.        , 0.        ,
#         2.        ]),
#  array([3.35714286, 3.17391304, 4.        , 3.        , 3.        ,
#         3.21875   , 0.        , 3.48101266, 3.14285714, 2.5       ,
#         2.9       , 4.        , 3.31578947, 3.12      , 3.27777778,
#         3.46031746, 3.76923077, 3.66666667, 1.        , 7.        ,
#         1.        ]),
#  array([2.28571429, 2.6       , 4.25      , 2.75      , 3.18181818,
#         1.        , 0.        , 3.25      , 0.        , 3.        ,
#         2.        , 5.        , 4.        , 3.27272727, 3.2       ,
#         2.8       , 2.        , 2.        , 0.        , 0.        ,
#         2.        ]),
#  array([4.        , 4.08571429, 4.5       , 4.27272727, 4.33333333,
#         4.13636364, 5.        , 4.14492754, 4.44444444, 4.33333333,
#         3.75      , 5.        , 4.44444444, 4.13333333, 4.00862069,
#         4.        , 4.5       , 4.        , 1.        , 1.        ,
#         4.        ]),
#  array([3.17322835, 3.35802469, 4.38095238, 3.85897436, 3.525     ,
#         3.45454545, 0.        , 3.96116505, 3.54545455, 4.33333333,
#         2.85714286, 4.5       , 4.        , 3.93181818, 3.45454545,
#         3.04761905, 4.        , 3.55555556, 0.        , 3.        ,
#         0.        ]),
#  array([ 3.64646465,  3.65909091,  3.66666667,  3.46666667,  3.87837838,
#          4.13333333,  3.        ,  3.82051282,  3.625     ,  4.        ,
#          3.25862069,  3.76470588,  3.        ,  3.85714286,  3.22222222,
#          3.40384615,  3.6       ,  2.5       ,  1.        , 10.        ,
#          6.        ]),
#  array([ 4.17647059,  3.75      ,  0.        ,  0.        ,  3.75      ,
#          4.2       ,  0.        ,  4.33333333,  0.        ,  5.        ,
#          4.        ,  0.        ,  4.5       ,  4.        ,  4.        ,
#          4.22222222,  4.66666667,  0.        ,  1.        , 14.        ,
#          1.        ]),
#  array([ 4.        ,  4.2       ,  3.07142857,  2.625     ,  3.        ,
#          1.        ,  0.        ,  1.        ,  0.        ,  3.        ,
#          1.        ,  2.        ,  1.        ,  5.        ,  4.        ,
#          2.        ,  3.        ,  3.        ,  1.        , 16.        ,
#          0.        ]),
#  array([ 2.73333333,  2.98039216,  3.54545455,  3.21052632,  3.18571429,
#          3.20833333,  4.        ,  3.52727273,  3.15384615,  4.        ,
#          3.06451613,  3.16666667,  2.54545455,  2.7       ,  2.94827586,
#          2.79545455,  3.42857143,  3.        ,  1.        , 15.        ,
#          0.        ]),
#  array([3.51515152, 3.41509434, 3.38461538, 2.81818182, 3.32608696,
#         3.35185185, 2.8       , 3.22222222, 2.85714286, 3.44444444,
#         3.63333333, 3.        , 3.13333333, 3.48148148, 3.4954955 ,
#         3.22222222, 3.54545455, 4.5       , 1.        , 0.        ,
#         2.        ]),
#  array([3.78571429, 3.84615385, 4.        , 4.5       , 3.93055556,
#         4.30769231, 4.        , 4.04545455, 4.        , 4.        ,
#         4.        , 4.28571429, 3.        , 3.97368421, 3.5       ,
#         4.8       , 4.4       , 3.33333333, 0.        , 7.        ,
#         1.        ]),
#  array([3.86666667, 4.        , 3.22222222, 3.5       , 3.66666667,
#         4.5       , 3.        , 3.89473684, 3.5       , 4.        ,
#         3.        , 2.        , 3.        , 4.2       , 3.72093023,
#         3.6875    , 3.92307692, 5.        , 1.        , 4.        ,
#         0.        ]),
#  array([3.04477612, 3.02857143, 2.75      , 2.51612903, 2.75115207,
#         3.08333333, 0.        , 3.42028986, 2.28571429, 4.        ,
#         2.15384615, 2.57142857, 2.76923077, 3.29411765, 2.90909091,
#         3.29166667, 2.92857143, 2.25      , 1.        , 7.        ,
#         1.        ]),
#  array([ 3.57142857,  3.66666667,  2.66666667,  2.83333333,  4.2       ,
#          4.83333333,  0.        ,  4.36      ,  2.88888889,  4.57142857,
#          2.5       ,  4.        ,  4.75      ,  3.55555556,  4.        ,
#          4.625     ,  4.83333333,  4.5       ,  1.        , 11.        ,
#          1.        ]),
#  array([3.89473684, 4.1       , 2.75      , 3.16666667, 3.80555556,
#         3.57142857, 0.        , 3.86956522, 3.25      , 3.83333333,
#         4.33333333, 3.5       , 3.6       , 4.04166667, 3.6       ,
#         3.45454545, 4.125     , 3.        , 0.        , 1.        ,
#         1.        ]),
#  array([3.54444444, 3.51724138, 4.        , 0.        , 3.54545455,
#         3.75      , 0.        , 3.66666667, 3.66666667, 3.        ,
#         3.57142857, 5.        , 3.        , 2.88888889, 3.51724138,
#         3.5       , 3.70588235, 4.33333333, 1.        , 7.        ,
#         2.        ]),
#  array([3.75      , 4.        , 3.        , 5.        , 3.375     ,
#         3.5       , 2.5       , 3.48148148, 5.        , 4.        ,
#         2.        , 2.        , 4.        , 3.5       , 4.33333333,
#         4.14285714, 4.5       , 0.        , 0.        , 7.        ,
#         2.        ]),
#  array([4.0625    , 4.36363636, 4.33333333, 4.33333333, 3.72641509,
#         4.28571429, 3.        , 3.42857143, 4.5       , 0.        ,
#         3.33333333, 4.14285714, 4.66666667, 3.86363636, 4.125     ,
#         4.2       , 3.6       , 4.        , 1.        , 7.        ,
#         5.        ]),
#  array([3.14285714, 2.5       , 3.25      , 3.        , 3.46153846,
#         3.6       , 0.        , 4.04761905, 4.        , 3.        ,
#         0.        , 3.        , 3.        , 4.11111111, 3.4       ,
#         3.63636364, 3.75      , 4.        , 0.        , 0.        ,
#         1.        ]),
#  array([3.94285714, 3.62162162, 3.        , 2.77777778, 3.09638554,
#         3.89189189, 3.66666667, 3.44171779, 3.42857143, 3.27272727,
#         3.56603774, 3.23529412, 3.58823529, 3.1627907 , 3.80851064,
#         3.80681818, 3.52173913, 3.25      , 1.        , 3.        ,
#         3.        ]),
#  array([3.94117647, 3.76923077, 4.4       , 4.11111111, 3.84166667,
#         4.2       , 0.        , 4.31707317, 3.75      , 0.        ,
#         3.5625    , 3.75      , 3.33333333, 3.79032258, 4.14285714,
#         3.66666667, 5.        , 4.        , 0.        , 0.        ,
#         0.        ]),
#  array([3.52631579, 3.8       , 2.6       , 3.09090909, 3.45945946,
#         3.71428571, 0.        , 3.73267327, 3.        , 3.5       ,
#         2.5       , 3.17857143, 3.90909091, 3.40983607, 3.5       ,
#         3.72222222, 3.69230769, 3.73333333, 1.        , 1.        ,
#         3.        ]),
#  array([4.1300813 , 4.04761905, 4.3       , 4.41176471, 4.14492754,
#         4.41935484, 4.5       , 4.33333333, 3.66666667, 4.2       ,
#         3.88888889, 3.75      , 4.33333333, 4.32653061, 4.        ,
#         4.21978022, 4.18421053, 4.        , 1.        , 3.        ,
#         1.        ]),
#  array([3.44444444, 3.        , 4.33333333, 4.25      , 3.93103448,
#         1.        , 0.        , 4.11111111, 2.        , 0.        ,
#         1.        , 4.71428571, 4.        , 4.07894737, 2.        ,
#         3.5       , 3.6       , 0.        , 0.        , 9.        ,
#         1.        ]),
#  array([3.42857143, 3.        , 3.875     , 3.71428571, 3.69387755,
#         3.66666667, 4.        , 3.56818182, 0.        , 0.        ,
#         0.        , 3.85714286, 3.        , 3.50819672, 3.5       ,
#         3.18181818, 4.5       , 0.        , 0.        , 4.        ,
#         0.        ]),
#  array([3.58333333, 3.8       , 4.2       , 4.        , 3.89285714,
#         3.85714286, 0.        , 3.72222222, 0.        , 5.        ,
#         3.        , 0.        , 4.33333333, 3.375     , 3.        ,
#         3.25      , 4.        , 0.        , 1.        , 4.        ,
#         0.        ]),
#  array([3.24489796, 3.45901639, 5.        , 3.5       , 3.35294118,
#         2.5       , 0.        , 3.95238095, 3.44444444, 5.        ,
#         3.        , 3.33333333, 3.        , 3.58333333, 3.29166667,
#         3.7       , 3.58536585, 3.        , 1.        , 0.        ,
#         3.        ]),
#  array([3.71428571, 5.        , 4.        , 4.        , 2.4       ,
#         0.        , 0.        , 3.66666667, 5.        , 0.        ,
#         2.2       , 5.        , 1.        , 3.71428571, 4.33333333,
#         2.66666667, 4.25      , 0.        , 0.        , 4.        ,
#         0.        ]),
#  array([3.792     , 3.80597015, 4.        , 3.81818182, 3.74576271,
#         3.58823529, 3.        , 3.68292683, 3.73913043, 5.        ,
#         3.53846154, 4.        , 4.        , 3.94736842, 3.79166667,
#         3.58928571, 4.16666667, 4.        , 1.        , 8.        ,
#         1.        ]),
#  array([ 4.        ,  5.        ,  5.        ,  5.        ,  4.2       ,
#          4.        ,  0.        ,  3.6       ,  0.        ,  0.        ,
#          0.        ,  5.        ,  0.        ,  4.14285714,  4.        ,
#          4.25      ,  5.        ,  0.        ,  1.        , 12.        ,
#          1.        ]),
#  array([ 3.78571429,  3.78461538,  4.5       ,  4.2       ,  3.89855072,
#          3.75      ,  0.        ,  3.66666667,  3.52      ,  4.        ,
#          2.32142857,  4.125     ,  3.1       ,  3.82758621,  3.69565217,
#          3.4375    ,  4.11111111,  3.5       ,  1.        , 17.        ,
#          3.        ]),
#  array([ 2.92307692,  3.16666667,  2.75      ,  2.78947368,  2.95744681,
#          2.5       ,  0.        ,  2.8       ,  3.28571429,  0.        ,
#          3.        ,  3.13333333,  3.6       ,  3.07333333,  3.53846154,
#          3.16666667,  3.14285714,  3.16666667,  0.        , 16.        ,
#          3.        ]),
#  array([ 2.33333333,  3.        ,  0.        ,  0.        ,  2.        ,
#          0.        ,  1.        ,  1.        ,  1.        ,  0.        ,
#          5.        ,  0.        ,  5.        ,  0.        ,  1.        ,
#          4.55555556,  0.        ,  0.        ,  1.        , 19.        ,
#          0.        ]),
#  array([3.66666667, 3.        , 0.        , 4.        , 3.66666667,
#         3.6       , 0.        , 4.        , 0.        , 0.        ,
#         0.        , 0.        , 0.        , 3.83333333, 0.        ,
#         2.66666667, 4.5       , 0.        , 1.        , 4.        ,
#         0.        ]),
#  array([3.06806283, 2.97368421, 3.39473684, 2.85057471, 2.8625    ,
#         3.30769231, 4.33333333, 3.32894737, 2.97142857, 3.75      ,
#         2.80952381, 3.51351351, 3.04347826, 3.20238095, 3.07692308,
#         3.17391304, 3.37735849, 3.08333333, 1.        , 4.        ,
#         1.        ]),
#  array([ 3.59375   ,  3.40740741,  3.58333333,  3.57894737,  3.375     ,
#          3.76923077,  4.        ,  4.13636364,  3.        ,  5.        ,
#          2.75      ,  3.5       ,  3.66666667,  3.7       ,  3.66666667,
#          3.82758621,  4.2       ,  0.        ,  1.        , 12.        ,
#          0.        ]),
#  array([3.        , 2.5       , 3.        , 3.        , 2.86666667,
#         3.        , 0.        , 3.4375    , 0.        , 0.        ,
#         3.        , 3.        , 3.        , 3.14285714, 3.25      ,
#         3.375     , 4.        , 4.        , 0.        , 2.        ,
#         1.        ]),
#  array([ 3.        ,  0.        ,  4.6       ,  4.5       ,  3.76923077,
#          3.        ,  0.        ,  4.15384615,  0.        ,  3.        ,
#          4.        ,  4.5       ,  3.        ,  3.85714286,  3.33333333,
#          3.83333333,  0.        ,  0.        ,  0.        , 10.        ,
#          6.        ]),
#  array([3.53968254, 3.        , 0.        , 0.        , 3.42105263,
#         3.25      , 0.        , 3.85714286, 2.        , 0.        ,
#         3.4       , 0.        , 2.75      , 3.5       , 3.54545455,
#         3.72727273, 4.28571429, 3.33333333, 1.        , 4.        ,
#         0.        ]),
#  array([3.98717949, 3.97701149, 4.11764706, 3.94827586, 4.26666667,
#         4.33333333, 5.        , 4.38095238, 4.        , 4.9       ,
#         4.06896552, 4.        , 4.22222222, 4.26804124, 4.00735294,
#         4.17834395, 4.5       , 4.1       , 1.        , 0.        ,
#         1.        ]),
#  array([4.        , 4.        , 2.        , 2.66666667, 4.02777778,
#         3.5       , 0.        , 4.        , 4.        , 0.        ,
#         5.        , 4.        , 4.        , 4.25      , 4.        ,
#         4.        , 4.        , 4.        , 1.        , 1.        ,
#         4.        ]),
#  array([ 5.        ,  4.        ,  4.66666667,  4.5       ,  4.66666667,
#          3.        ,  3.        ,  4.07692308,  0.        ,  0.        ,
#          0.        ,  0.        ,  0.        ,  4.        ,  5.        ,
#          4.14285714,  4.75      ,  3.        ,  0.        , 12.        ,
#          2.        ]),
#  array([ 4.25      ,  0.        ,  5.        ,  5.        ,  3.92592593,
#          4.41666667,  5.        ,  3.78125   ,  0.        ,  5.        ,
#          0.        ,  5.        ,  5.        ,  3.625     ,  3.        ,
#          4.        ,  4.22222222,  0.        ,  1.        , 20.        ,
#          2.        ]),
#  array([ 2.77777778,  2.5       ,  3.5       ,  2.71428571,  3.        ,
#          2.66666667,  0.        ,  3.78947368,  0.        ,  0.        ,
#          2.33333333,  3.        ,  1.        ,  1.        ,  2.88888889,
#          2.45454545,  3.8       ,  0.        ,  1.        , 19.        ,
#          0.        ]),
#  array([3.7030303 , 3.74074074, 4.52380952, 4.03125   , 4.05172414,
#         4.28571429, 4.5       , 4.27067669, 4.16666667, 5.        ,
#         3.70454545, 4.1875    , 4.27777778, 4.11363636, 3.62091503,
#         3.71428571, 4.48571429, 3.71428571, 1.        , 2.        ,
#         1.        ]),
#  array([3.33333333, 3.41666667, 3.66666667, 3.71428571, 3.35849057,
#         3.        , 2.        , 3.52173913, 3.5       , 3.77777778,
#         2.        , 3.73333333, 3.81818182, 3.61290323, 3.0625    ,
#         3.52380952, 3.92592593, 3.83333333, 0.        , 1.        ,
#         4.        ]),
#  array([3.43478261, 3.62068966, 4.5       , 4.5       , 3.11538462,
#         3.375     , 0.        , 3.41666667, 4.25      , 2.5       ,
#         2.66666667, 0.        , 3.33333333, 3.90909091, 3.58333333,
#         3.73684211, 3.25      , 3.        , 1.        , 1.        ,
#         4.        ]),
#  array([ 2.8       ,  1.6       ,  3.        ,  3.        ,  3.        ,
#          2.5       ,  0.        ,  3.8       ,  1.        ,  0.        ,
#          2.75      ,  0.        ,  3.        ,  2.66666667,  2.5       ,
#          2.625     ,  4.        ,  0.        ,  1.        , 17.        ,
#          1.        ]),
#  array([3.30120482, 3.33333333, 4.42857143, 4.        , 3.42138365,
#         3.61904762, 4.66666667, 3.64049587, 2.90909091, 3.83333333,
#         3.1875    , 3.7       , 3.75      , 3.35051546, 3.32075472,
#         3.52439024, 3.66666667, 3.84615385, 0.        , 3.        ,
#         2.        ]),
#  array([3.26666667, 3.33333333, 4.6       , 3.75      , 3.375     ,
#         4.2       , 3.5       , 3.69444444, 0.        , 4.5       ,
#         3.30769231, 0.        , 4.        , 3.55555556, 3.36363636,
#         2.79166667, 4.6       , 0.        , 1.        , 4.        ,
#         0.        ]),
#  array([4.2       , 4.25      , 5.        , 0.        , 4.6       ,
#         0.        , 0.        , 4.42857143, 0.        , 0.        ,
#         3.83333333, 4.        , 4.        , 4.        , 3.8       ,
#         3.55555556, 4.66666667, 0.        , 1.        , 1.        ,
#         0.        ]),
#  array([ 4.44827586,  4.26470588,  4.6       ,  4.125     ,  4.14285714,
#          4.44444444,  5.        ,  4.40909091,  4.        ,  4.        ,
#          4.        ,  4.        ,  5.        ,  4.0625    ,  4.21052632,
#          4.55172414,  4.4375    ,  0.        ,  1.        , 12.        ,
#          2.        ]),
#  array([ 4.42857143,  3.5       ,  2.        ,  1.75      ,  3.63636364,
#          0.        ,  0.        ,  4.90909091,  2.        ,  0.        ,
#          2.        ,  2.        ,  0.        ,  5.        ,  3.75      ,
#          2.        ,  4.85714286,  0.        ,  1.        , 18.        ,
#          1.        ]),
#  array([4.        , 3.66666667, 0.        , 0.        , 3.84615385,
#         4.85714286, 0.        , 4.44444444, 0.        , 5.        ,
#         4.        , 4.        , 0.        , 4.3       , 3.        ,
#         4.16666667, 4.        , 4.        , 0.        , 5.        ,
#         4.        ]),
#  array([3.        , 4.        , 4.2       , 4.33333333, 3.90566038,
#         3.75      , 5.        , 3.95238095, 4.        , 0.        ,
#         3.        , 4.16666667, 5.        , 3.57142857, 3.5       ,
#         4.33333333, 3.5       , 1.6       , 1.        , 4.        ,
#         0.        ]),
#  array([3.6       , 3.        , 0.        , 0.        , 3.9       ,
#         4.75      , 0.        , 4.15873016, 0.        , 0.        ,
#         0.        , 0.        , 0.        , 4.28571429, 3.33333333,
#         4.66666667, 4.        , 2.        , 0.        , 1.        ,
#         1.        ]),
#  array([3.3       , 4.5       , 4.33333333, 3.5       , 4.04545455,
#         3.        , 0.        , 3.88235294, 3.        , 5.        ,
#         3.        , 3.5       , 3.        , 4.        , 3.33333333,
#         3.33333333, 1.5       , 0.        , 1.        , 4.        ,
#         0.        ]),
#  array([ 4.11111111,  4.33333333,  0.        ,  0.        ,  3.85714286,
#          3.66666667,  0.        ,  3.55555556,  0.        ,  3.        ,
#          3.        ,  4.        ,  3.5       ,  3.        ,  4.33333333,
#          3.5       ,  4.        ,  0.        ,  1.        , 14.        ,
#          1.        ]),
#  array([3.75      , 2.5       , 0.        , 0.        , 3.53846154,
#         3.        , 0.        , 3.81818182, 2.        , 0.        ,
#         0.        , 0.        , 0.        , 4.2       , 2.75      ,
#         3.83333333, 4.5       , 5.        , 0.        , 0.        ,
#         3.        ]),
#  array([3.35099338, 3.22857143, 3.88888889, 3.22222222, 3.54736842,
#         3.35      , 0.        , 3.63636364, 3.72727273, 0.        ,
#         3.57894737, 3.33333333, 3.        , 3.64705882, 3.2375    ,
#         3.23880597, 3.83333333, 2.75      , 1.        , 4.        ,
#         0.        ]),
#  array([ 3.66666667,  0.        ,  0.        ,  1.5       ,  3.64285714,
#          4.33333333,  4.        ,  4.        ,  0.        ,  5.        ,
#          0.        ,  3.5       ,  4.16666667,  3.6       ,  0.        ,
#          4.25      ,  4.        ,  3.        ,  1.        , 14.        ,
#          2.        ]),
#  array([ 3.88888889,  3.95652174,  3.59677419,  3.8880597 ,  4.26506024,
#          0.        ,  0.        ,  4.15789474,  4.13636364,  0.        ,
#          0.        ,  3.44827586,  4.        ,  3.81818182,  4.25      ,
#          4.33333333,  3.8       ,  5.        ,  0.        , 10.        ,
#          6.        ]),
#  array([3.66666667, 3.        , 4.28571429, 4.5       , 4.16666667,
#         4.4375    , 0.        , 4.25      , 0.        , 5.        ,
#         0.        , 0.        , 4.33333333, 4.4       , 3.83333333,
#         4.28571429, 3.66666667, 0.        , 1.        , 7.        ,
#         2.        ]),
#  array([2.75      , 1.        , 4.5       , 5.        , 3.41176471,
#         0.        , 0.        , 2.88235294, 0.        , 0.        ,
#         2.        , 0.        , 0.        , 2.75      , 1.        ,
#         2.4       , 3.        , 0.        , 1.        , 4.        ,
#         0.        ]),
#  array([3.        , 3.        , 3.42857143, 3.51851852, 3.58490566,
#         3.5       , 0.        , 3.90625   , 3.25      , 0.        ,
#         0.        , 3.60465116, 3.        , 3.78125   , 4.        ,
#         3.5       , 4.66666667, 3.        , 0.        , 1.        ,
#         3.        ]),
#  array([3.5       , 3.        , 3.        , 3.        , 3.        ,
#         3.5       , 0.        , 3.83333333, 3.        , 4.        ,
#         3.66666667, 5.        , 3.78571429, 3.        , 3.25      ,
#         3.81818182, 0.        , 0.        , 0.        , 0.        ,
#         3.        ]),
#  array([3.92307692, 3.75      , 3.11111111, 3.        , 3.41666667,
#         4.5       , 0.        , 4.38095238, 3.        , 0.        ,
#         0.        , 3.2       , 0.        , 4.11111111, 3.57142857,
#         4.        , 4.25      , 5.        , 1.        , 1.        ,
#         5.        ]),
#  array([4.66666667, 4.        , 3.        , 0.        , 4.19047619,
#         4.76923077, 3.        , 4.52631579, 5.        , 4.72727273,
#         4.6       , 4.        , 4.66666667, 4.25      , 4.2       ,
#         4.3125    , 4.71428571, 4.        , 0.        , 0.        ,
#         1.        ]),
#  array([ 3.875     ,  4.        ,  0.        ,  0.        ,  4.        ,
#          3.9       ,  0.        ,  4.23529412,  4.        ,  4.        ,
#          3.55555556,  0.        ,  3.52941176,  4.125     ,  3.7       ,
#          3.94915254,  4.71428571,  4.        ,  1.        , 17.        ,
#          1.        ]),
#  array([3.52173913, 3.67857143, 3.66666667, 3.55      , 3.27027027,
#         3.        , 0.        , 3.91666667, 3.66666667, 4.5       ,
#         2.83333333, 4.        , 3.        , 3.88235294, 3.70588235,
#         3.5       , 5.        , 1.        , 0.        , 2.        ,
#         1.        ]),
#  array([4.19047619, 3.75      , 0.        , 0.        , 3.57142857,
#         3.33333333, 0.        , 4.33333333, 3.        , 0.        ,
#         3.66666667, 0.        , 0.        , 4.5       , 3.85714286,
#         4.        , 4.44444444, 0.        , 1.        , 4.        ,
#         0.        ]),
#  array([3.        , 3.5       , 1.        , 1.        , 3.25      ,
#         2.        , 3.        , 3.29411765, 0.        , 0.        ,
#         3.        , 1.        , 2.        , 2.5       , 3.66666667,
#         3.33333333, 2.        , 0.        , 1.        , 4.        ,
#         0.        ]),
#  array([ 4.53846154,  4.28571429,  4.        ,  4.        ,  4.09090909,
#          4.        ,  0.        ,  4.5       ,  4.5       ,  5.        ,
#          4.33333333,  3.8       ,  4.75      ,  4.4       ,  4.5       ,
#          4.7       ,  4.5       ,  5.        ,  0.        , 10.        ,
#          6.        ]),
#  array([ 3.01960784,  3.72727273,  1.        ,  1.        ,  1.88888889,
#          2.6       ,  1.        ,  3.        ,  5.        ,  0.        ,
#          3.        ,  1.        ,  0.        ,  2.125     ,  3.54545455,
#          3.9       ,  3.2       ,  2.5       ,  1.        , 14.        ,
#          1.        ]),
#  array([4.33333333, 4.        , 0.        , 0.        , 3.82608696,
#         4.83333333, 0.        , 4.4375    , 0.        , 3.66666667,
#         1.        , 0.        , 3.75      , 4.        , 3.33333333,
#         4.5       , 4.25      , 0.        , 0.        , 1.        ,
#         3.        ]),
#  array([4.16666667, 5.        , 0.        , 0.        , 1.66666667,
#         4.        , 0.        , 4.44444444, 0.        , 0.        ,
#         0.        , 0.        , 0.        , 5.        , 0.        ,
#         4.5       , 4.66666667, 0.        , 0.        , 9.        ,
#         5.        ]),
#  array([ 3.68253968,  3.4       ,  3.16666667,  2.9       ,  3.52325581,
#          3.92857143,  0.        ,  3.36111111,  3.4       ,  4.4       ,
#          3.375     ,  2.75      ,  3.77777778,  3.16666667,  3.42857143,
#          3.56060606,  3.33333333,  4.        ,  1.        , 13.        ,
#          5.        ]),
#  array([5.        , 5.        , 0.        , 0.        , 4.75675676,
#         5.        , 0.        , 4.61538462, 5.        , 0.        ,
#         5.        , 4.        , 4.        , 5.        , 0.        ,
#         3.        , 4.83333333, 5.        , 1.        , 7.        ,
#         2.        ]),
#  array([2.56      , 2.69565217, 2.875     , 2.95454545, 2.98170732,
#         2.86666667, 0.        , 2.56701031, 2.8       , 4.        ,
#         2.18181818, 3.42592593, 2.3       , 2.84722222, 2.71428571,
#         2.29166667, 2.625     , 2.75      , 0.        , 4.        ,
#         0.        ]),
#  array([ 2.89130435,  2.92405063,  3.47368421,  2.92      ,  3.08333333,
#          2.625     ,  0.        ,  3.34782609,  3.37037037,  3.        ,
#          3.09090909,  2.4       ,  2.5       ,  3.16      ,  3.21212121,
#          2.92424242,  3.26315789,  2.8       ,  1.        , 17.        ,
#          1.        ]),
#  array([ 4.33333333,  4.        ,  3.        ,  4.        ,  4.5       ,
#          0.        ,  0.        ,  4.        ,  0.        ,  0.        ,
#          3.82352941,  5.        ,  0.        ,  0.        ,  4.2       ,
#          3.75      ,  0.        ,  0.        ,  1.        , 17.        ,
#          1.        ]),
#  array([3.66666667, 3.57142857, 3.        , 3.        , 3.52631579,
#         3.4       , 0.        , 3.675     , 0.        , 1.        ,
#         2.        , 3.        , 3.33333333, 3.5       , 3.66666667,
#         3.67741935, 4.        , 4.        , 1.        , 0.        ,
#         3.        ]),
#  array([ 3.84210526,  3.88888889,  3.4       ,  3.625     ,  3.47619048,
#          3.66666667,  0.        ,  3.72340426,  4.5       ,  4.        ,
#          0.        ,  4.        ,  3.5       ,  3.72727273,  3.83333333,
#          3.72222222,  4.        ,  2.66666667,  0.        , 16.        ,
#          1.        ]),
#  array([4.36363636, 4.54545455, 4.5       , 4.5       , 4.47619048,
#         4.64285714, 0.        , 4.46969697, 4.5       , 4.61538462,
#         4.09090909, 4.5       , 4.61538462, 4.65      , 4.25      ,
#         4.6       , 4.44444444, 4.        , 0.        , 3.        ,
#         2.        ]),
#  array([4.        , 3.5       , 0.        , 0.        , 3.28571429,
#         3.5       , 0.        , 4.625     , 0.        , 0.        ,
#         1.5       , 1.        , 4.        , 3.66666667, 2.66666667,
#         3.5       , 4.6       , 0.        , 0.        , 7.        ,
#         2.        ]),
#  array([ 3.46666667,  3.66666667,  3.75      ,  3.53846154,  3.3       ,
#          4.18181818,  0.        ,  3.10638298,  3.5       ,  0.        ,
#          4.        ,  3.8       ,  3.        ,  2.91666667,  3.        ,
#          3.        ,  3.66666667,  4.        ,  0.        , 10.        ,
#          6.        ]),
#  array([ 2.9516129 ,  3.09090909,  0.        ,  5.        ,  2.72727273,
#          3.16666667,  0.        ,  3.54166667,  3.5       ,  3.        ,
#          3.        ,  5.        ,  3.25      ,  2.92857143,  3.        ,
#          2.92857143,  3.07142857,  3.        ,  1.        , 17.        ,
#          2.        ]),
#  array([4.67676768, 4.76190476, 0.        , 5.        , 4.7826087 ,
#         4.5       , 0.        , 4.73684211, 5.        , 0.        ,
#         3.75      , 0.        , 5.        , 4.83333333, 4.58823529,
#         4.42424242, 4.75      , 5.        , 0.        , 3.        ,
#         0.        ]),
#  array([ 2.95      ,  3.        ,  2.875     ,  2.55555556,  3.06666667,
#          3.75      ,  0.        ,  2.90384615,  1.5       ,  4.83333333,
#          3.5       ,  2.33333333,  3.75      ,  3.125     ,  3.29411765,
#          3.39285714,  4.5       ,  1.5       ,  1.        , 19.        ,
#          2.        ]),
#  array([4.04950495, 4.05882353, 4.5       , 3.42857143, 3.68421053,
#         4.        , 0.        , 4.31578947, 1.5       , 0.        ,
#         4.6       , 4.75      , 3.        , 3.7       , 4.25641026,
#         4.        , 4.4       , 0.        , 1.        , 7.        ,
#         3.        ]),
#  array([ 3.6       ,  3.5       ,  4.        ,  4.        ,  3.38888889,
#          3.75      ,  0.        ,  3.46666667,  0.        ,  3.        ,
#          3.75      ,  0.        ,  0.        ,  2.        ,  3.16666667,
#          3.72727273,  5.        ,  3.        ,  1.        , 12.        ,
#          1.        ]),
#  array([ 4.33333333,  4.61538462,  0.        ,  0.        ,  4.5       ,
#          4.25      ,  0.        ,  4.17647059,  4.66666667,  0.        ,
#          4.5       ,  3.        ,  0.        ,  4.22222222,  4.375     ,
#          3.76470588,  4.5       ,  5.        ,  1.        , 12.        ,
#          3.        ]),
#  array([ 4.4       ,  4.        ,  4.5       ,  4.        ,  4.08695652,
#          0.        ,  0.        ,  3.76190476,  4.        ,  0.        ,
#          4.        ,  4.5       ,  4.        ,  4.02380952,  4.        ,
#          4.        ,  4.33333333,  0.        ,  0.        , 11.        ,
#          2.        ]),
#  array([ 3.92857143,  4.33333333,  4.        ,  4.33333333,  3.36842105,
#          3.66666667,  4.        ,  3.78571429,  4.        ,  3.625     ,
#          3.83333333,  3.55555556,  4.28571429,  3.52941176,  4.11111111,
#          3.7037037 ,  4.        ,  3.75      ,  1.        , 18.        ,
#          3.        ]),
#  array([ 3.36363636,  3.28571429,  3.5       ,  1.5       ,  3.35714286,
#          4.        ,  1.        ,  3.375     ,  0.        ,  0.        ,
#          2.5       ,  2.25      ,  3.        ,  2.33333333,  2.85714286,
#          3.14285714,  3.5       ,  2.        ,  1.        , 12.        ,
#          1.        ]),
#  array([ 4.2       ,  4.25      ,  4.        ,  4.        ,  4.02222222,
#          4.        ,  0.        ,  3.5       ,  4.11111111,  4.        ,
#          5.        ,  3.92307692,  3.75      ,  4.        ,  4.05      ,
#          3.85714286,  4.25      ,  4.        ,  1.        , 15.        ,
#          3.        ]),
#  array([2.75      , 2.8       , 0.        , 0.        , 3.04545455,
#         3.38      , 0.        , 3.92      , 3.5       , 5.        ,
#         2.33333333, 0.        , 3.125     , 3.71428571, 2.75      ,
#         3.36      , 4.        , 0.        , 1.        , 2.        ,
#         1.        ]),
#  array([ 3.41666667,  3.4       ,  3.66666667,  3.        ,  3.89189189,
#          4.        ,  4.        ,  3.82222222,  4.        ,  5.        ,
#          0.        ,  3.        ,  3.8       ,  3.91304348,  3.5       ,
#          3.35294118,  4.25      ,  5.        ,  1.        , 15.        ,
#          2.        ]),
#  array([ 5.        ,  4.33333333,  4.08571429,  4.18518519,  4.16666667,
#          4.85714286,  0.        ,  4.16666667,  4.        ,  4.56521739,
#          2.        ,  3.85714286,  4.5       ,  4.        ,  4.        ,
#          4.        ,  0.        ,  0.        ,  1.        , 16.        ,
#          1.        ]),
#  array([ 3.73333333,  3.83333333,  4.        ,  3.        ,  3.14285714,
#          3.        ,  1.        ,  4.35294118,  0.        ,  0.        ,
#          1.5       ,  3.        ,  4.        ,  3.66666667,  3.67857143,
#          3.90909091,  4.4       ,  0.        ,  1.        , 12.        ,
#          0.        ]),
#  array([3.5       , 3.90909091, 3.76190476, 3.69014085, 3.24242424,
#         0.        , 0.        , 4.        , 4.15384615, 0.        ,
#         4.        , 4.11111111, 4.        , 3.36363636, 4.        ,
#         5.        , 3.        , 3.        , 0.        , 2.        ,
#         1.        ]),
#  array([ 4.30769231,  3.66666667,  4.66666667,  4.5       ,  4.66666667,
#          4.5       ,  0.        ,  4.16666667,  0.        ,  0.        ,
#          3.44444444,  3.33333333,  3.        ,  0.        ,  4.16666667,
#          3.75      ,  5.        ,  0.        ,  1.        , 17.        ,
#          1.        ]),
#  array([ 3.59259259,  4.13333333,  4.        ,  4.375     ,  3.84615385,
#          3.44444444,  0.        ,  3.73913043,  4.33333333,  4.        ,
#          3.81818182,  0.        ,  5.        ,  4.        ,  4.33333333,
#          3.5       ,  4.6       ,  3.        ,  1.        , 17.        ,
#          1.        ]),
#  array([ 3.56632653,  3.57142857,  3.42307692,  3.265625  ,  3.03636364,
#          3.38095238,  1.        ,  3.37179487,  3.55882353,  4.        ,
#          3.05882353,  3.34210526,  3.14285714,  3.67647059,  3.49350649,
#          3.33684211,  3.63333333,  3.0625    ,  1.        , 17.        ,
#          1.        ]),
#  array([ 3.77118644,  3.78461538,  3.8       ,  3.2       ,  3.80681818,
#          3.76923077,  0.        ,  3.81818182,  3.3       ,  3.66666667,
#          3.33333333,  3.5       ,  4.        ,  4.17021277,  3.75510204,
#          3.85714286,  4.07692308,  4.5       ,  1.        , 17.        ,
#          2.        ]),
#  array([ 3.77777778,  3.28571429,  3.40625   ,  3.4137931 ,  3.66071429,
#          0.        ,  0.        ,  3.5       ,  3.        ,  3.        ,
#          3.42857143,  3.54545455,  3.75      ,  4.        ,  3.5       ,
#          4.        ,  2.        ,  4.        ,  0.        , 10.        ,
#          6.        ]),
#  array([ 3.15789474,  3.66666667,  4.        ,  4.        ,  3.85714286,
#          3.92857143,  0.        ,  3.88888889,  5.        ,  0.        ,
#          2.8       ,  4.        ,  3.        ,  3.5       ,  3.28571429,
#          3.        ,  4.14285714,  3.        ,  1.        , 11.        ,
#          1.        ]),
#  array([4.54285714, 4.33333333, 4.6       , 3.83333333, 4.38888889,
#         4.5       , 0.        , 4.66666667, 3.4       , 5.        ,
#         4.3125    , 5.        , 5.        , 4.75      , 4.60784314,
#         4.09090909, 4.6       , 3.        , 1.        , 7.        ,
#         2.        ]),
#  array([2.88461538, 2.63157895, 1.        , 0.        , 3.        ,
#         3.33333333, 0.        , 3.46153846, 3.        , 0.        ,
#         2.5       , 4.        , 0.        , 3.5       , 2.72222222,
#         2.94117647, 3.28571429, 4.        , 0.        , 4.        ,
#         0.        ]),
#  array([3.42857143, 3.43333333, 3.        , 3.2       , 3.11052632,
#         3.68852459, 0.        , 3.59215686, 3.5       , 3.71428571,
#         3.275     , 3.5       , 3.44827586, 3.22535211, 3.42553191,
#         3.50684932, 3.90243902, 3.38461538, 1.        , 9.        ,
#         2.        ]),
#  array([3.8       , 3.        , 0.        , 4.5       , 4.        ,
#         4.33333333, 0.        , 4.33333333, 0.        , 5.        ,
#         0.        , 0.        , 0.        , 4.        , 3.        ,
#         4.        , 4.        , 0.        , 1.        , 7.        ,
#         5.        ]),
#  array([ 4.22222222,  4.23076923,  0.        ,  0.        ,  4.        ,
#          3.83333333,  0.        ,  4.19047619,  4.        ,  4.        ,
#          4.33333333,  0.        ,  4.        ,  3.85714286,  4.23076923,
#          4.0952381 ,  4.45454545,  4.5       ,  1.        , 14.        ,
#          3.        ]),
#  array([3.76470588, 4.        , 0.        , 0.        , 4.06666667,
#         4.        , 0.        , 3.92592593, 5.        , 4.        ,
#         0.        , 4.5       , 4.5       , 4.44      , 4.66666667,
#         3.75      , 4.66666667, 0.        , 1.        , 9.        ,
#         0.        ]),
#  array([4.02985075, 4.        , 3.25      , 3.83333333, 3.71875   ,
#         3.78947368, 3.        , 3.83823529, 3.8       , 4.66666667,
#         4.33333333, 0.        , 3.625     , 3.72727273, 4.04878049,
#         3.85294118, 4.1       , 4.        , 0.        , 3.        ,
#         3.        ]),
#  array([4.6       , 4.33333333, 5.        , 5.        , 4.11111111,
#         0.        , 0.        , 4.2       , 4.        , 0.        ,
#         5.        , 4.75      , 0.        , 4.33333333, 4.75      ,
#         5.        , 4.        , 3.        , 1.        , 6.        ,
#         5.        ]),
#  array([ 4.06896552,  3.82051282,  4.        ,  2.5       ,  3.83783784,
#          4.13333333,  0.        ,  4.2       ,  3.5       ,  4.57142857,
#          4.5       ,  5.        ,  4.44444444,  4.        ,  3.74074074,
#          4.2       ,  4.16666667,  4.33333333,  1.        , 11.        ,
#          1.        ]),
#  array([ 4.53636364,  4.47058824,  3.        ,  5.        ,  4.26315789,
#          4.        ,  0.        ,  4.42857143,  5.        ,  4.        ,
#          4.09090909,  4.66666667,  4.5       ,  4.        ,  4.28571429,
#          4.17142857,  4.8       ,  4.        ,  1.        , 17.        ,
#          2.        ]),
#  array([2.94444444, 3.        , 3.38461538, 3.09090909, 3.27777778,
#         3.31818182, 3.8       , 3.53548387, 3.        , 4.        ,
#         3.15384615, 2.63636364, 3.3       , 3.23404255, 3.14285714,
#         3.30612245, 3.5       , 2.5       , 1.        , 4.        ,
#         0.        ]),
#  array([ 3.77777778,  4.        ,  3.75      ,  3.90909091,  4.02298851,
#          3.25      ,  0.        ,  3.77777778,  3.75      ,  0.        ,
#          3.        ,  3.75      ,  3.        ,  3.61538462,  4.        ,
#          3.        ,  0.        ,  3.        ,  1.        , 17.        ,
#          1.        ]),
#  array([3.57142857, 2.71428571, 5.        , 3.75      , 3.54166667,
#         3.91666667, 0.        , 3.97826087, 3.25      , 4.        ,
#         2.76923077, 4.33333333, 4.11111111, 4.125     , 2.77777778,
#         3.7826087 , 4.33333333, 4.5       , 0.        , 0.        ,
#         1.        ]),
#  array([2.4488189 , 2.44444444, 4.        , 3.125     , 3.07272727,
#         2.47058824, 0.        , 3.35294118, 2.5       , 0.        ,
#         1.6       , 3.2       , 2.4       , 2.36842105, 2.40983607,
#         2.43103448, 3.2       , 2.25      , 1.        , 0.        ,
#         1.        ]),
#  array([3.5       , 4.28571429, 4.85714286, 4.5       , 3.88235294,
#         4.        , 0.        , 3.64705882, 0.        , 4.        ,
#         2.71428571, 4.5       , 3.25      , 4.        , 3.33333333,
#         2.86666667, 5.        , 1.        , 1.        , 4.        ,
#         0.        ]),
#  array([2.19047619, 2.94594595, 2.55172414, 2.88      , 2.9245283 ,
#         2.53333333, 3.54545455, 3.328     , 3.15      , 3.14285714,
#         3.58064516, 2.84444444, 3.6875    , 2.74137931, 2.8627451 ,
#         2.86046512, 3.22222222, 1.75      , 1.        , 2.        ,
#         0.        ]),
#  array([3.74193548, 3.78787879, 3.8       , 3.875     , 3.55769231,
#         3.47826087, 0.        , 3.68115942, 3.8       , 3.5       ,
#         3.1875    , 3.375     , 3.35294118, 3.48214286, 3.76470588,
#         3.55769231, 3.88235294, 4.        , 0.        , 6.        ,
#         3.        ]),
#  array([ 4.26315789,  4.        ,  5.        ,  5.        ,  4.66666667,
#          4.51351351,  0.        ,  4.5       ,  4.        ,  4.5       ,
#          4.        ,  0.        ,  4.4       ,  4.14285714,  4.33333333,
#          4.41176471,  4.        ,  0.        ,  1.        , 20.        ,
#          0.        ]),
#  array([ 3.93150685,  3.96296296,  3.91428571,  3.87804878,  3.82051282,
#          4.25      ,  4.625     ,  4.12962963,  4.5       ,  4.2       ,
#          3.43243243,  3.57142857,  4.33333333,  4.2       ,  3.83333333,
#          3.83333333,  4.09090909,  3.25      ,  0.        , 20.        ,
#          1.        ]),
#  array([4.09090909, 3.57142857, 3.        , 3.        , 4.        ,
#         4.2       , 2.        , 4.05      , 4.        , 3.85714286,
#         3.5       , 2.66666667, 3.71428571, 4.55555556, 4.33333333,
#         3.72727273, 4.33333333, 0.        , 0.        , 1.        ,
#         2.        ]),
#  array([ 3.25      ,  4.        ,  3.        ,  3.        ,  3.        ,
#          2.5       ,  0.        ,  4.11111111,  0.        ,  4.33333333,
#          0.        ,  0.        ,  3.875     ,  3.66666667,  2.33333333,
#          4.25      ,  4.5       ,  4.        ,  1.        , 13.        ,
#          2.        ]),
#  array([3.33333333, 4.        , 4.        , 3.77777778, 3.41666667,
#         4.        , 2.        , 3.25      , 3.66666667, 3.        ,
#         0.        , 3.6       , 3.        , 2.        , 3.42857143,
#         2.77777778, 3.66666667, 1.        , 1.        , 7.        ,
#         1.        ]),
#  array([3.62068966, 3.4       , 2.5       , 4.        , 3.51724138,
#         0.        , 0.        , 3.72      , 0.        , 0.        ,
#         2.        , 0.        , 4.5       , 3.5       , 3.        ,
#         3.44444444, 3.66666667, 0.        , 1.        , 3.        ,
#         0.        ]),
#  array([ 3.44444444,  3.        ,  3.        ,  2.        ,  1.875     ,
#          3.6       ,  5.        ,  4.38461538,  0.        ,  0.        ,
#          1.        ,  3.        ,  4.        ,  2.33333333,  3.11111111,
#          3.625     ,  3.75      ,  1.        ,  1.        , 17.        ,
#          1.        ]),
#  array([2.8       , 1.5       , 4.        , 1.33333333, 2.88235294,
#         3.66666667, 0.        , 3.        , 1.        , 0.        ,
#         3.5       , 2.        , 2.        , 3.        , 1.66666667,
#         2.        , 0.        , 0.        , 1.        , 4.        ,
#         0.        ]),
#  array([ 3.609375  ,  3.46666667,  3.8       ,  3.55813953,  3.86805556,
#          4.1       ,  0.        ,  3.74074074,  2.86666667,  4.18181818,
#          3.75      ,  3.88679245,  3.85      ,  3.6952381 ,  3.52380952,
#          3.93650794,  4.18181818,  3.        ,  0.        , 20.        ,
#          2.        ]),
#  array([3.36363636, 3.44186047, 3.33333333, 3.27272727, 3.475     ,
#         3.25      , 2.        , 3.83076923, 3.30769231, 4.        ,
#         2.75      , 2.33333333, 3.25      , 3.56666667, 3.4375    ,
#         3.46428571, 3.80769231, 3.5       , 1.        , 4.        ,
#         0.        ]),
#  array([ 3.7372549 ,  3.79032258,  3.95833333,  3.82608696,  3.78333333,
#          3.51612903,  4.        ,  3.7357513 ,  3.6       ,  3.66666667,
#          3.78571429,  3.48275862,  3.31818182,  3.75      ,  3.60504202,
#          3.7398374 ,  3.71698113,  3.84615385,  1.        , 17.        ,
#          4.        ]),
#  array([3.72131148, 3.78571429, 3.55555556, 3.72727273, 4.08484848,
#         3.84337349, 4.33333333, 4.0234375 , 4.09090909, 4.18181818,
#         3.88888889, 4.55555556, 3.625     , 4.01298701, 3.81967213,
#         3.75816993, 4.4047619 , 4.66666667, 1.        , 1.        ,
#         1.        ]),
#  array([3.75      , 3.66666667, 3.88888889, 4.08333333, 3.9125    ,
#         4.16666667, 3.        , 4.234375  , 4.        , 4.25      ,
#         3.57142857, 4.375     , 4.11111111, 3.86111111, 4.        ,
#         4.        , 4.23529412, 3.83333333, 1.        , 7.        ,
#         2.        ]),
#  array([ 3.59      ,  3.44444444,  2.75      ,  3.13333333,  3.73706897,
#          4.25806452,  0.        ,  3.67816092,  3.38095238,  4.        ,
#          3.30769231,  3.90909091,  3.28571429,  3.43274854,  3.52631579,
#          3.56      ,  3.7826087 ,  3.33333333,  0.        , 20.        ,
#          1.        ]),
#  array([4.33333333, 4.66666667, 4.        , 4.        , 4.4       ,
#         5.        , 0.        , 4.14285714, 0.        , 0.        ,
#         3.33333333, 0.        , 0.        , 3.33333333, 0.        ,
#         3.33333333, 0.        , 0.        , 1.        , 4.        ,
#         0.        ]),
#  array([ 0.        ,  3.5       ,  3.5       ,  2.        ,  3.94444444,
#          5.        ,  0.        ,  4.4       ,  2.        ,  0.        ,
#          3.33333333,  1.        ,  0.        ,  5.        ,  3.        ,
#          4.5       ,  0.        ,  0.        ,  1.        , 10.        ,
#          6.        ]),
#  array([ 3.125     ,  2.25      ,  2.8       ,  2.8       ,  3.26666667,
#          3.75      ,  0.        ,  3.125     ,  0.        ,  5.        ,
#          2.6       ,  3.33333333,  0.        ,  3.5       ,  2.25      ,
#          3.25      ,  3.        ,  0.        ,  1.        , 20.        ,
#          4.        ]),
#  array([ 3.1       ,  2.77777778,  1.        ,  2.33333333,  2.59459459,
#          4.        ,  0.        ,  4.03333333,  3.        ,  0.        ,
#          2.        ,  3.66666667,  5.        ,  3.76923077,  3.375     ,
#          4.2       ,  3.42857143,  2.        ,  1.        , 12.        ,
#          2.        ]),
#  array([3.8       , 4.2       , 4.66666667, 4.        , 4.27272727,
#         3.42857143, 0.        , 4.23214286, 3.        , 3.5       ,
#         2.        , 4.5       , 4.        , 4.20731707, 4.5       ,
#         4.07142857, 4.41666667, 4.        , 0.        , 7.        ,
#         3.        ]),
#  array([ 3.62015504,  3.4556962 ,  4.        ,  3.52941176,  3.59487179,
#          3.92592593,  4.        ,  3.89864865,  2.91666667,  4.35714286,
#          3.75      ,  3.61538462,  4.23076923,  3.57627119,  3.62195122,
#          3.80597015,  4.20454545,  3.7       ,  1.        , 16.        ,
#          2.        ]),
#  array([4.66666667, 4.5       , 4.        , 4.5       , 3.75      ,
#         4.5       , 0.        , 4.2       , 0.        , 4.        ,
#         2.        , 4.        , 4.5       , 4.        , 0.        ,
#         4.75      , 4.33333333, 0.        , 1.        , 7.        ,
#         5.        ]),
#  array([4.        , 3.66666667, 3.8       , 3.75      , 3.61904762,
#         5.        , 0.        , 3.88888889, 0.        , 4.        ,
# ...
#          3.625     ,  4.        ,  3.84705882,  3.42857143,  3.76923077,
#          3.59459459,  4.10714286,  3.28571429,  3.69642857,  3.34126984,
#          3.44444444,  4.03030303,  4.24      ,  1.        , 12.        ,
#          5.        ]),
#  array([ 3.83333333,  4.0754717 ,  4.5       ,  3.94117647,  3.83950617,
#          3.5       ,  0.        ,  3.96666667,  4.4375    ,  5.        ,
#          3.97222222,  4.        ,  3.54545455,  3.67741935,  4.15286624,
#          3.69148936,  4.19354839,  3.875     ,  1.        , 17.        ,
#          4.        ]),
#  array([2.90909091, 2.92857143, 4.        , 2.5       , 3.        ,
#         2.        , 0.        , 3.33333333, 3.        , 0.        ,
#         2.2       , 0.        , 2.5       , 4.        , 2.96153846,
#         2.91666667, 3.        , 2.        , 1.        , 7.        ,
#         2.        ]),
#  array([4.        , 4.        , 4.53333333, 4.75      , 4.85714286,
#         0.        , 0.        , 4.5       , 0.        , 5.        ,
#         5.        , 4.        , 0.        , 0.        , 3.        ,
#         4.66666667, 0.        , 0.        , 1.        , 2.        ,
#         3.        ]),
#  array([ 3.88888889,  3.5       ,  4.66666667,  4.14285714,  3.97752809,
#          3.88888889,  5.        ,  4.05      ,  3.5       ,  4.        ,
#          4.        ,  3.5       ,  3.33333333,  4.        ,  3.55555556,
#          4.        ,  4.71428571,  0.        ,  1.        , 16.        ,
#          5.        ]),
#  array([ 4.60465116,  4.47368421,  4.76470588,  4.64285714,  4.57142857,
#          4.86363636,  4.77777778,  4.75675676,  5.        ,  4.9       ,
#          4.75      ,  4.76923077,  4.63157895,  4.65517241,  4.7037037 ,
#          4.78787879,  4.68181818,  4.25      ,  1.        , 20.        ,
#          4.        ]),
#  array([3.39130435, 3.84615385, 4.        , 3.85714286, 3.8       ,
#         3.2       , 0.        , 3.86666667, 4.25      , 4.        ,
#         3.28571429, 3.83333333, 4.        , 3.375     , 3.92307692,
#         3.58823529, 3.3       , 4.        , 0.        , 0.        ,
#         1.        ]),
#  array([3.46153846, 3.45454545, 4.16666667, 3.27272727, 3.6969697 ,
#         3.7       , 2.25      , 3.67808219, 3.13043478, 4.4       ,
#         3.125     , 2.66666667, 3.33333333, 3.71666667, 3.2       ,
#         3.575     , 4.26666667, 3.85714286, 0.        , 7.        ,
#         4.        ]),
#  array([4.27777778, 4.5       , 3.75      , 3.95      , 4.05405405,
#         3.8       , 4.        , 3.875     , 4.66666667, 4.5       ,
#         3.        , 3.95833333, 4.        , 4.13333333, 4.07692308,
#         3.6875    , 4.5       , 0.        , 1.        , 1.        ,
#         2.        ]),
#  array([4.19444444, 4.5625    , 4.14285714, 4.08333333, 4.12328767,
#         4.37037037, 4.66666667, 4.31277533, 5.        , 4.75      ,
#         3.81818182, 4.16666667, 4.7       , 4.17948718, 4.27777778,
#         4.17073171, 4.74074074, 4.75      , 1.        , 1.        ,
#         2.        ]),
#  array([3.375     , 3.        , 4.66666667, 3.33333333, 3.75510204,
#         4.        , 3.875     , 4.33823529, 4.        , 4.36363636,
#         3.21428571, 3.8       , 4.375     , 4.07142857, 2.88888889,
#         3.72727273, 4.46153846, 4.        , 1.        , 2.        ,
#         2.        ]),
#  array([ 3.81818182,  3.9375    ,  3.25      ,  3.2       ,  3.33333333,
#          3.25      ,  0.        ,  3.80952381,  3.5       ,  2.        ,
#          0.        ,  3.85714286,  3.2       ,  3.62162162,  3.85714286,
#          3.77419355,  3.8125    ,  4.        ,  1.        , 11.        ,
#          4.        ]),
#  array([ 3.6       ,  3.5       ,  4.        ,  3.6       ,  3.67391304,
#          4.5       ,  4.25      ,  4.22033898,  3.75      ,  4.        ,
#          3.71428571,  5.        ,  3.44444444,  3.89473684,  4.        ,
#          3.78571429,  4.375     ,  0.        ,  1.        , 10.        ,
#          6.        ]),
#  array([ 4.        ,  3.33333333,  3.        ,  2.66666667,  3.94736842,
#          4.        ,  0.        ,  3.76923077,  0.        ,  0.        ,
#          3.5       ,  0.        ,  4.        ,  3.66666667,  3.33333333,
#          3.81818182,  4.5       ,  0.        ,  1.        , 10.        ,
#          0.        ]),
#  array([4.125     , 3.        , 0.        , 2.        , 3.69230769,
#         3.8       , 4.5       , 4.        , 0.        , 5.        ,
#         0.        , 0.        , 5.        , 3.66666667, 5.        ,
#         4.19230769, 4.33333333, 4.        , 0.        , 1.        ,
#         1.        ]),
#  array([3.54054054, 3.35087719, 3.57894737, 3.45833333, 3.19760479,
#         3.5       , 3.5       , 3.68      , 3.1875    , 3.5       ,
#         3.16666667, 3.875     , 3.06451613, 3.27692308, 3.49382716,
#         3.34722222, 4.03846154, 3.75      , 1.        , 0.        ,
#         1.        ]),
#  array([2.84615385, 2.85714286, 4.44444444, 4.5       , 3.8627451 ,
#         4.        , 0.        , 3.9047619 , 0.        , 0.        ,
#         2.25      , 4.28571429, 2.        , 3.83333333, 2.90909091,
#         3.        , 3.5       , 3.        , 1.        , 7.        ,
#         1.        ]),
#  array([3.875     , 4.66666667, 4.3       , 4.41666667, 4.16666667,
#         4.08333333, 0.        , 4.07317073, 4.        , 4.75      ,
#         3.5       , 4.26315789, 4.4       , 3.71428571, 3.5       ,
#         4.15384615, 4.625     , 0.        , 1.        , 7.        ,
#         5.        ]),
#  array([4.        , 2.33333333, 3.        , 3.        , 3.12903226,
#         4.5       , 3.5       , 3.75      , 0.        , 4.        ,
#         1.33333333, 2.        , 4.5       , 3.88235294, 2.57142857,
#         3.        , 4.625     , 0.        , 1.        , 2.        ,
#         5.        ]),
#  array([3.        , 3.        , 4.        , 4.        , 3.63793103,
#         2.75      , 0.        , 3.83333333, 3.        , 0.        ,
#         3.17647059, 4.        , 2.75      , 3.94117647, 2.66666667,
#         3.30769231, 5.        , 0.        , 0.        , 0.        ,
#         0.        ]),
#  array([ 3.7       ,  3.5       ,  5.        ,  0.        ,  4.23529412,
#          4.44444444,  0.        ,  4.21052632,  0.        ,  5.        ,
#          3.        ,  0.        ,  4.5       ,  4.14285714,  3.83333333,
#          4.13333333,  4.        ,  5.        ,  1.        , 12.        ,
#          4.        ]),
#  array([ 3.        ,  4.        ,  3.        ,  0.        ,  4.        ,
#          4.5       ,  5.        ,  4.46153846,  4.        ,  5.        ,
#          0.        ,  0.        ,  5.        ,  3.8       ,  0.        ,
#          4.75      ,  5.        ,  0.        ,  0.        , 11.        ,
#          1.        ]),
#  array([3.0375    , 3.10958904, 3.75      , 3.77777778, 3.16438356,
#         3.08928571, 1.        , 3.33146067, 2.875     , 3.33333333,
#         2.88461538, 3.6       , 2.81818182, 3.3490566 , 2.93103448,
#         3.07655502, 3.51612903, 2.85714286, 1.        , 0.        ,
#         1.        ]),
#  array([ 3.3       ,  3.43661972,  4.        ,  3.52941176,  3.42222222,
#          3.46341463,  0.        ,  3.675     ,  3.5862069 ,  4.        ,
#          3.11538462,  0.        ,  3.15384615,  3.4       ,  3.20879121,
#          3.21666667,  4.        ,  3.        ,  1.        , 12.        ,
#          1.        ]),
#  array([3.25      , 3.33333333, 0.        , 4.        , 3.91666667,
#         4.        , 0.        , 3.64285714, 0.        , 0.        ,
#         2.33333333, 2.33333333, 2.66666667, 3.        , 3.2       ,
#         4.16666667, 3.4       , 1.        , 1.        , 1.        ,
#         3.        ]),
#  array([3.53846154, 3.5483871 , 3.        , 3.47058824, 3.32142857,
#         2.44444444, 4.25      , 3.61904762, 3.41666667, 1.5       ,
#         2.33333333, 3.5       , 2.88888889, 3.59574468, 3.28571429,
#         2.71428571, 3.83333333, 4.        , 0.        , 1.        ,
#         1.        ]),
#  array([ 3.68965517,  3.75      ,  3.2       ,  3.        ,  3.88888889,
#          3.66666667,  0.        ,  3.44444444,  4.        ,  0.        ,
#          2.5       ,  3.        ,  0.        ,  4.25      ,  4.        ,
#          4.        ,  4.        ,  0.        ,  1.        , 19.        ,
#          2.        ]),
#  array([3.37864078, 3.04285714, 1.66666667, 2.        , 2.78632479,
#         3.63888889, 4.125     , 3.42941176, 3.27272727, 3.77777778,
#         3.05263158, 2.        , 3.72      , 2.96460177, 3.4       ,
#         3.50588235, 3.325     , 3.36363636, 1.        , 0.        ,
#         2.        ]),
#  array([ 3.27272727,  3.4       ,  3.        ,  3.        ,  3.55      ,
#          3.        ,  0.        ,  3.21428571,  4.        ,  5.        ,
#          3.2       ,  3.        ,  5.        ,  2.66666667,  3.4       ,
#          3.2       ,  4.        ,  3.        ,  1.        , 14.        ,
#          2.        ]),
#  array([3.64912281, 3.48148148, 2.83333333, 4.        , 3.51764706,
#         3.9047619 , 4.        , 3.94444444, 3.5       , 3.57142857,
#         3.79591837, 3.        , 3.875     , 3.375     , 3.58928571,
#         3.80487805, 4.06666667, 3.625     , 1.        , 2.        ,
#         1.        ]),
#  array([3.16666667, 0.        , 4.        , 1.        , 3.35714286,
#         3.        , 4.        , 4.44444444, 4.        , 5.        ,
#         2.83333333, 4.5       , 4.        , 4.        , 4.2       ,
#         3.44444444, 4.66666667, 0.        , 1.        , 0.        ,
#         0.        ]),
#  array([ 4.14285714,  3.76470588,  3.        ,  3.        ,  4.03333333,
#          4.33333333,  0.        ,  3.78571429,  3.25      ,  0.        ,
#          0.        ,  0.        ,  3.5       ,  3.875     ,  3.81818182,
#          4.5       ,  4.5       ,  5.        ,  1.        , 10.        ,
#          6.        ]),
#  array([3.25454545, 3.46153846, 2.64864865, 2.23333333, 2.9375    ,
#         2.33333333, 5.        , 3.59375   , 2.2       , 4.33333333,
#         3.8       , 2.44444444, 4.5       , 3.15384615, 3.61904762,
#         3.65      , 3.53333333, 3.5       , 1.        , 6.        ,
#         1.        ]),
#  array([ 3.175     ,  3.03846154,  3.3       ,  3.11111111,  3.41111111,
#          3.65      ,  3.83333333,  3.28571429,  2.75      ,  3.4       ,
#          3.33333333,  3.        ,  3.375     ,  3.        ,  3.16666667,
#          3.40740741,  3.40909091,  4.5       ,  1.        , 20.        ,
#          1.        ]),
#  array([4.83333333, 4.57142857, 5.        , 4.5       , 4.15      ,
#         0.        , 0.        , 4.        , 4.5       , 0.        ,
#         0.        , 5.        , 0.        , 4.14893617, 5.        ,
#         4.5       , 4.33333333, 0.        , 0.        , 9.        ,
#         1.        ]),
#  array([ 4.1875    ,  4.37142857,  4.        ,  4.2       ,  4.05882353,
#          3.33333333,  0.        ,  4.21428571,  4.25      ,  3.        ,
#          4.        ,  4.        ,  0.        ,  4.25      ,  4.30769231,
#          3.4       ,  3.44444444,  0.        ,  0.        , 16.        ,
#          1.        ]),
#  array([ 3.52409639,  3.51086957,  3.        ,  3.04651163,  3.34285714,
#          3.76086957,  4.        ,  3.65769231,  3.09090909,  4.11111111,
#          3.4137931 ,  3.55172414,  3.625     ,  3.67368421,  3.51136364,
#          3.66666667,  3.86153846,  3.59259259,  1.        , 16.        ,
#          4.        ]),
#  array([4.06666667, 4.        , 4.5       , 4.41666667, 4.4375    ,
#         4.04545455, 0.        , 4.17142857, 4.75      , 4.4       ,
#         4.25      , 4.16666667, 4.13043478, 4.        , 4.1       ,
#         4.16666667, 4.28571429, 4.        , 1.        , 4.        ,
#         1.        ]),
#  array([4.5       , 3.        , 0.        , 0.        , 3.        ,
#         0.        , 0.        , 3.91666667, 0.        , 0.        ,
#         4.2       , 4.        , 0.        , 0.        , 3.75      ,
#         4.        , 5.        , 0.        , 0.        , 0.        ,
#         5.        ]),
#  array([ 3.6       ,  4.        ,  4.        ,  3.66666667,  4.10843373,
#          4.2       ,  4.        ,  4.13095238,  3.25      ,  3.66666667,
#          2.5       ,  3.5       ,  4.22222222,  3.96078431,  3.75862069,
#          3.93333333,  4.        ,  3.        ,  0.        , 17.        ,
#          2.        ]),
#  array([ 3.64705882,  3.5       ,  0.        ,  4.        ,  3.77419355,
#          4.42857143,  0.        ,  4.03030303,  3.66666667,  0.        ,
#          4.33333333,  4.5       ,  0.        ,  3.88888889,  3.44444444,
#          4.        ,  4.5       ,  0.        ,  1.        , 11.        ,
#          4.        ]),
#  array([4.5       , 4.5       , 4.83333333, 4.66666667, 4.90909091,
#         5.        , 0.        , 4.42857143, 0.        , 4.875     ,
#         5.        , 4.63636364, 4.88888889, 4.57142857, 4.5       ,
#         4.625     , 4.5       , 5.        , 1.        , 0.        ,
#         4.        ]),
#  array([3.73469388, 3.875     , 4.        , 3.66666667, 3.48148148,
#         3.77777778, 0.        , 3.4       , 1.        , 0.        ,
#         3.5       , 0.        , 0.        , 3.6875    , 3.75      ,
#         3.54545455, 3.75      , 3.        , 1.        , 6.        ,
#         0.        ]),
#  array([3.625     , 3.85714286, 3.        , 2.66666667, 3.8       ,
#         0.        , 0.        , 3.58333333, 3.        , 0.        ,
#         0.        , 3.42857143, 4.66666667, 3.80392157, 3.25      ,
#         4.75      , 3.5       , 0.        , 0.        , 9.        ,
#         1.        ]),
#  array([5.        , 5.        , 0.        , 0.        , 3.29411765,
#         2.        , 5.        , 3.35294118, 0.        , 0.        ,
#         3.        , 5.        , 0.        , 3.57142857, 0.        ,
#         3.        , 3.5       , 0.        , 0.        , 3.        ,
#         2.        ]),
#  array([3.47058824, 3.66666667, 2.        , 3.        , 3.26315789,
#         4.14285714, 0.        , 3.33333333, 3.66666667, 0.        ,
#         3.        , 0.        , 3.        , 3.57142857, 3.16666667,
#         3.        , 3.375     , 4.        , 1.        , 0.        ,
#         1.        ]),
#  array([4.19354839, 4.        , 4.        , 4.5       , 3.6       ,
#         4.33333333, 0.        , 4.26666667, 4.        , 0.        ,
#         4.        , 5.        , 0.        , 3.71428571, 4.125     ,
#         4.22222222, 4.        , 4.        , 1.        , 2.        ,
#         0.        ]),
#  array([3.4       , 3.        , 3.        , 3.        , 3.875     ,
#         3.        , 0.        , 3.86666667, 4.        , 0.        ,
#         0.        , 4.        , 4.        , 3.93478261, 4.        ,
#         4.        , 4.        , 0.        , 0.        , 4.        ,
#         0.        ]),
#  array([ 3.8880597 ,  3.79661017,  3.76923077,  4.        ,  3.81034483,
#          4.06976744,  4.25      ,  4.17582418,  4.1       ,  4.4       ,
#          3.64705882,  4.        ,  3.78947368,  4.        ,  3.78571429,
#          3.85714286,  4.21052632,  4.1       ,  1.        , 17.        ,
#          1.        ]),
#  array([ 4.2       ,  4.25      ,  3.5       ,  3.5       ,  3.91666667,
#          3.        ,  0.        ,  4.07142857,  0.        ,  0.        ,
#          2.        ,  0.        ,  0.        ,  4.        ,  4.2       ,
#          4.14285714,  4.66666667,  0.        ,  1.        , 19.        ,
#          6.        ]),
#  array([ 3.33333333,  4.        ,  3.83333333,  4.        ,  4.125     ,
#          3.55555556,  4.66666667,  4.075     ,  5.        ,  4.        ,
#          3.        ,  4.        ,  4.        ,  4.26315789,  4.5       ,
#          3.83333333,  4.25      ,  0.        ,  1.        , 20.        ,
#          3.        ]),
#  array([ 3.07860262,  3.02816901,  0.        ,  3.25      ,  3.11111111,
#          3.275     ,  0.        ,  3.34649123,  2.81818182,  0.        ,
#          2.78571429,  3.        ,  3.36363636,  3.18      ,  3.0483871 ,
#          3.18446602,  3.19444444,  3.66666667,  1.        , 15.        ,
#          1.        ]),
#  array([4.11320755, 3.9375    , 4.04761905, 4.        , 4.125     ,
#         4.6       , 0.        , 4.33333333, 3.25      , 4.        ,
#         3.66666667, 3.9       , 0.        , 3.5       , 4.1875    ,
#         4.125     , 4.25      , 4.5       , 0.        , 6.        ,
#         1.        ]),
#  ...]

# %% [markdown]
# ## Εφαρμόζουμε τον kmeans με το ολοκληρωμένο dataset αυτή τη φορά

# %%
kmeans = KMeans(n_clusters=5) # δοκιμάζουμε με 5 clusters
kmeans.fit(kmeans_complete_dataset)
# Out:
# KMeans(n_clusters=5)

# %%
predictions = kmeans.predict(kmeans_complete_dataset)
predictions
# Out:
# array([3, 4, 1, ..., 2, 0, 3], dtype=int32)

# %%
predictions.size
# Out:
# 6040

# %% [markdown]
# ### Θέλουμε να αντιστοιχίσουμε τους users με την ομάδα στην οποία ανήκουν (από τις προβλέψεις του kmeans)

# %%
users_clustered = pd.DataFrame(columns=['user_id', 'cluster'])

# %%
i = 0
for uid in user_ids:
    users_clustered = users_clustered.append({'user_id': uid, 'cluster': predictions[i]}, ignore_index=True)
    i += 1

# %%
users_clustered
# Out:
#      user_id cluster
# 0          1       3
# 1          2       4
# 2          3       1
# 3          4       3
# 4          5       1
# ...      ...     ...
# 6035    6036       1
# 6036    6037       0
# 6037    6038       2
# 6038    6039       0
# 6039    6040       3
#
# [6040 rows x 2 columns]

# %% [markdown]
# ### Μπορούμε τώρα να βρούμε όλους τους χρήστες που ανήκουν στο ίδιο cluster

# %%
# πχ cluster για τον user με id = 23
users_clustered[users_clustered['user_id']==23]
# Out:
#    user_id cluster
# 22      23       0

# %%
num = users_clustered[users_clustered['user_id']==23].cluster.values[0]
num
# Out:
# 0

# %%
# users στο ίδιο cluster
users_same_cluster = users_clustered[users_clustered.cluster == num]
users_same_cluster
# Out:
#      user_id cluster
# 9         10       0
# 12        13       0
# 15        16       0
# 16        17       0
# 17        18       0
# ...      ...     ...
# 6022    6023       0
# 6024    6025       0
# 6030    6031       0
# 6036    6037       0
# 6038    6039       0
#
# [1687 rows x 2 columns]

# %%
# id των user το ίδο cluster
user_ids_same_cluster = users_same_cluster.user_id.values
user_ids_same_cluster
# Out:
# array([10, 13, 16, ..., 6031, 6037, 6039], dtype=object)

# %% [markdown]
# ### Χρησιμοποιώντας τα ids των user που βρίσκονται στην ίδια ομάδα, μπορούμε να πάρουμε όλες τις βαθμολογίες τους από το  ratings_df

# %%
related_users_ratings = pd.DataFrame()
for user_id in user_ids_same_cluster:
    current_ratings = ratings_df[ratings_df['user_id']==user_id].drop(['timestamp'], axis=1)
    related_users_ratings = related_users_ratings.append(current_ratings)

# %%
related_users_ratings
# Out:
#         user_id  movie_id  rating
# 799          10      2622       5
# 800          10       648       4
# 801          10      2628       3
# 802          10      3358       5
# 803          10      3359       3
# ...         ...       ...     ...
# 999863     6039      1081       4
# 999864     6039      1083       3
# 999865     6039      1086       4
# 999866     6039      1088       4
# 999867     6039      1097       4
#
# [398151 rows x 3 columns]

# %%
# Αριθμός βαθμολογιών για κάθε ταινία
movie_id_counts = related_users_ratings.movie_id.value_counts()
movie_id_counts
# Out:
# 2858    1138
# 1196    1065
# 260     1056
# 1210     964
# 2571     929
#         ...
# 1868       1
# 3151       1
# 3523       1
# 2673       1
# 2895       1
# Name: movie_id, Length: 3604, dtype: int64

# %%
# Ταινίες με τουλάχιστον 10 βαθμολογίες από διαφορετικούς χρήστες
frequently_rated_movies = movie_id_counts[movie_id_counts >= 10]
frequently_rated_movies
# Out:
# 2858    1138
# 1196    1065
# 260     1056
# 1210     964
# 2571     929
#         ...
# 3580      10
# 3520      10
# 3222      10
# 3473      10
# 2678      10
# Name: movie_id, Length: 2972, dtype: int64

# %%
# array με ids ταινιών με τουλάχιστων 10 βαθμολογίες από διαφορετικούς χρήστες
frequently_rated_movies_ids = frequently_rated_movies.index
frequently_rated_movies_ids
# Out:
# Int64Index([2858, 1196,  260, 1210, 2571, 1270,  593,  589,  480, 2028,
#             ...
#             3781,  525, 2809,  274, 1812, 3580, 3520, 3222, 3473, 2678],
#            dtype='int64', length=2972)

# %% [markdown]
# #### Διαγράφουμε τις βαθμολογίες των ταινιών που έχουν βαθμολογηθεί από <10 χρήστες (για να μην χαλάσει το average)
# -> https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.isin.html

# %%
related_users_ratings = related_users_ratings[related_users_ratings.movie_id.isin(frequently_rated_movies_ids)]
related_users_ratings
# Out:
#         user_id  movie_id  rating
# 799          10      2622       5
# 800          10       648       4
# 801          10      2628       3
# 802          10      3358       5
# 803          10      3359       3
# ...         ...       ...     ...
# 999863     6039      1081       4
# 999864     6039      1083       3
# 999865     6039      1086       4
# 999866     6039      1088       4
# 999867     6039      1097       4
#
# [395620 rows x 3 columns]

# %% [markdown]
# ### Έτσι μπορούμε να βρούμε την average βαθμολογία μιας ταινίας σύμφωνα με τις βαθμολογίες των χρηστών σε ένα συγκεκριμένο cluster

# %%
related_users_avg_ratings_per_movie = related_users_ratings.groupby('movie_id').rating.mean()
related_users_avg_ratings_per_movie
# Out:
# movie_id
# 1       4.196154
# 2       3.183051
# 3       2.903409
# 4       2.758621
# 5       3.094017
#           ...
# 3948    3.765306
# 3949    4.107143
# 3950    3.400000
# 3951    4.133333
# 3952    3.623077
# Name: rating, Length: 2972, dtype: float64

# %% [markdown]
# ### Τέλος βρίσκουμε για ένα συγκεκριμένο χρήστη τις ταινίες τις οποίες ΔΕΝ έχει βαθμολογήσει και συμπληρώνουμε τις βαθμολογίες αυτές με το average rating των χρηστών που ανήκουν στο ίδιο cluster

# %%
# ταινίες που ΔΕΝ έχει βαθμολογήσει ο χρήστης με id = 23 (για παράδειγμα)
user_complete_ratings = ratings_df[ratings_df['user_id'] == 23]
user_ratings_merged = movies_df.merge(user_complete_ratings, on='movie_id', how='left').drop(['user_id', 'timestamp', 'genres'], axis=1)
user_incomplete_ratings = user_ratings_merged[user_ratings_merged.rating.isna()]

user_incomplete_ratings
# Out:
#       movie_id                               title  rating
# 2            3             Grumpier Old Men (1995)     NaN
# 3            4            Waiting to Exhale (1995)     NaN
# 4            5  Father of the Bride Part II (1995)     NaN
# 6            7                      Sabrina (1995)     NaN
# 7            8                 Tom and Huck (1995)     NaN
# ...        ...                                 ...     ...
# 3877      3947                   Get Carter (1971)     NaN
# 3878      3948             Meet the Parents (2000)     NaN
# 3879      3949          Requiem for a Dream (2000)     NaN
# 3880      3950                    Tigerland (2000)     NaN
# 3881      3951             Two Family House (2000)     NaN
#
# [3579 rows x 3 columns]

# %% [markdown]
# #### Συμπληρώνουμε όλες τις βαθμολογίες από το related_users_avg_ratings_per_movie
# -> https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.fillna.html
#
# -> https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.set_index.html

# %%
type(related_users_avg_ratings_per_movie)
# Out:
# pandas.core.series.Series

# %%
# Βάζουμε σαν index το movie_id εφόσον το αντικείμενο related_users_avg_ratings_per_movie είναι pandas.Series με indexes τα movie ids
user_updated_ratings = user_incomplete_ratings.set_index('movie_id').rating.fillna(related_users_avg_ratings_per_movie).reset_index()
user_updated_ratings
# Out:
#       movie_id    rating
# 0            3  2.903409
# 1            4  2.758621
# 2            5  3.094017
# 3            7  3.360656
# 4            8  2.935484
# ...        ...       ...
# 3574      3947  3.437500
# 3575      3948  3.765306
# 3576      3949  4.107143
# 3577      3950  3.400000
# 3578      3951  4.133333
#
# [3579 rows x 2 columns]

# %% [markdown]
# ## Χρησιμοποιώντας τα updated ratings μπορούμε να τα κάνουμε sort και να δώσουμε στο χρήστη recommendations

# %%
user_updated_ratings = user_updated_ratings.sort_values(by='rating', ascending=False)
user_updated_ratings.head(10)
# Out:
#       movie_id    rating
# 2598      2905  4.666667
# 606        669  4.666667
# 1786      2019  4.568093
# 838        922  4.560976
# 285        318  4.554133
# 607        670  4.500000
# 479        527  4.493333
# 1088      1198  4.480984
# 1074      1178  4.463918
# 291        326  4.448276

# %%
# Merge για να πάρουμε και τους τίτλους των ταινιών
final_result = user_updated_ratings.merge(movies_df, on='movie_id', how='left')
final_result.head(10)
# Out:
#    movie_id    rating                                              title  \
# 0      2905  4.666667                                     Sanjuro (1962)
# 1       669  4.666667                                   Aparajito (1956)
# 2      2019  4.568093  Seven Samurai (The Magnificent Seven) (Shichin...
# 3       922  4.560976      Sunset Blvd. (a.k.a. Sunset Boulevard) (1950)
# 4       318  4.554133                   Shawshank Redemption, The (1994)
# 5       670  4.500000             World of Apu, The (Apur Sansar) (1959)
# 6       527  4.493333                            Schindler's List (1993)
# 7      1198  4.480984                     Raiders of the Lost Ark (1981)
# 8      1178  4.463918                              Paths of Glory (1957)
# 9       326  4.448276                            To Live (Huozhe) (1994)
#
#              genres
# 0  Action|Adventure
# 1             Drama
# 2      Action|Drama
# 3         Film-Noir
# 4             Drama
# 5             Drama
# 6         Drama|War
# 7  Action|Adventure
# 8         Drama|War
# 9             Drama
